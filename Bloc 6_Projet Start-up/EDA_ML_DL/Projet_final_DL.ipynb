# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json
pd.options.display.max_columns = None # to see all the columns
pd.set_option('display.float_format', '{:.3g}'.format)

# %% [markdown]
# # Importer de données

# %%
df = pd.read_csv("data_ML_avec_outliers.csv").drop('Unnamed: 0', axis = 'columns')
df.head(2)
# Out:
#            name  funding_total_usd   status  funding_rounds  \
# 0  1 Mainstream              5e+06  success               1
# 1  1000 Markets              5e+05  success               1
#
#            Industry_Group  funding_day  funding_range_1_2  company_age  \
# 0  Information Technology     1.11e+03                  0           10
# 1      Media & Publishing          134                  0           13
#
#   Continent_Name
# 0  North America
# 1  North America

# %%
df["funding_range_1_2"].min()
# Out:
# 0.0

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 8705
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               8703 non-null   object
#  1   funding_total_usd  8703 non-null   float64
#  2   status             8703 non-null   object
#  3   funding_rounds     8703 non-null   int64
#  4   Industry_Group     8703 non-null   object
#  5   funding_day        8703 non-null   float64
#  6   funding_range_1_2  8703 non-null   float64
#  7   company_age        8703 non-null   int64
#  8   Continent_Name     8703 non-null   object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 679.9+ KB

# %% [markdown]
# # Preprocessing

# %%
from matplotlib.cbook import boxplot_stats

# %%
for status, data in df.groupby('status'):
    data = data.loc[:, ["funding_total_usd"]]  # drop off the species column
    print(f'Outliers for: {status}')
    stats = boxplot_stats(data)
    print(stats)
# Out:
# Outliers for: failure
# [{'mean': 14183414.330113515, 'iqr': 20715168.75, 'cilo': 1440093.3975074221, 'cihi': 2559906.602492578, 'whishi': 52000000.0, 'whislo': 100.0, 'fliers': array([5.1000000e+08, 6.0000000e+07, 1.0500000e+08, 1.2050000e+08,
#        1.2500000e+08, 1.1000000e+08, 1.0900000e+08, 6.0100000e+07,
#        5.6300000e+07, 7.0930000e+07, 8.0000000e+07, 1.2000000e+08,
#        1.9666413e+08, 5.9500000e+07, 5.9463636e+07, 8.9500000e+07,
#        5.5000000e+07, 1.2000000e+08, 1.4220000e+08, 1.4153571e+08,
#        6.7400000e+07, 6.3500000e+07, 6.0900000e+07, 9.9670000e+07,
#        5.9000000e+07, 6.7000000e+07, 7.6700000e+07, 1.3030000e+08,
#        5.8000000e+07, 6.6000000e+07, 5.5346470e+07, 1.5630454e+08,
#        5.8000000e+07, 6.0000000e+07, 9.6800000e+07, 7.3000000e+07,
#        1.2340000e+08, 5.0000000e+08, 6.5000000e+07, 9.0000000e+07,
#        1.0830000e+08, 6.0000000e+07, 6.0000000e+07, 7.5000000e+07,
#        1.0680000e+08, 6.4800004e+07, 9.8900000e+07, 9.0200000e+07,
#        5.2500000e+07, 5.5600000e+07, 1.2596485e+08, 5.8200000e+07,
#        6.4600000e+07, 7.0000000e+07, 7.0000000e+07, 5.4000000e+07,
#        9.2253800e+07, 8.5300000e+07, 7.5000000e+07, 5.5000000e+07,
#        5.3999988e+07, 8.0500000e+07, 9.2505380e+07, 1.2500000e+08,
#        1.8532501e+08, 1.2570000e+08, 1.0300000e+08, 1.1656805e+08,
#        3.6587296e+08, 6.2800000e+07, 7.4000000e+07, 6.0800000e+07,
#        5.5900000e+07, 8.2120000e+07, 2.1140300e+08, 1.5675043e+09,
#        1.42000000e+08, 1.24309780e+08, 1.55180000e+08, 3.10000000e+08,
#        2.00000000e+09, 1.12254776e+08, 9.66279800e+07, 1.67062160e+08,
#        1.09693280e+08, 1.58688880e+08, 1.22987970e+08, 1.38600000e+08,
#        8.66550800e+08, 1.49938640e+08, 1.20000000e+08, 2.10384740e+08,
#        3.96000000e+08, 8.76780000e+08, 4.81200000e+09, 1.67000000e+08,
#        1.61200000e+08, 1.18500000e+08, 1.10000000e+08, 4.20000000e+08,
#        2.98000000e+08, 6.70000000e+08, 4.46000000e+08, 3.26000000e+08,
#        1.81850000e+08, 9.50000000e+08, 1.05400000e+08, 1.15000000e+08,
#        7.06500000e+08, 5.75400000e+08, 8.90000000e+08, 4.78000000e+08,
#        5.86000000e+08, 4.63000000e+09, 2.39000000e+08, 1.26000000e+08,
#        6.95000000e+08, 1.80500000e+08, 9.34700000e+07, 1.32000000e+09,
#        1.34200000e+09, 1.34200000e+09, 1.02400000e+08, 1.02400000e+08,
#        1.00000000e+08, 1.13000000e+08, 1.00000000e+08, 1.58750000e+08,
#        1.53721620e+08, 4.00000000e+08, 1.76000000e+08, 1.59968500e+08,
#        9.50000000e+07, 3.09700000e+08, 9.47348800e+07, 1.39847580e+08,
#        1.07500000e+08, 9.90000000e+07, 1.33314584e+08, 1.79200000e+08,
#        2.44500000e+08, 1.08000000e+08, 1.03139680e+08, 1.66570000e+08,
#        2.50000000e+08, 2.32329400e+08, 1.06550010e+08, 9.79490100e+07,
#        1.20500000e+08, 2.57944300e+08, 9.30000000e+07, 6.00397250e+08,
#        1.10755160e+08, 1.08377224e+08, 1.06185470e+08, 1.26000000e+08,
#        1.11950000e+09, 9.22757600e+07, 1.00000000e+09, 1.10000000e+08,
#        3.90000000e+08, 1.58261600e+08, 1.00000000e+08, 2.51000000e+08,
#        1.22000000e+08, 4.86000000e+08, 3.74995300e+08, 3.21184540e+08,
#        3.00000000e+08, 9.05052100e+07, 1.50000000e+08, 1.86036240e+08,
#        1.27620230e+08, 1.91229400e+08, 1.98007660e+08, 1.52197920e+08,
#        1.24592504e+08, 2.00000000e+08, 9.40000000e+07, 2.00000000e+08,
#        1.00000000e+08, 1.03000010e+08, 9.62500000e+07, 4.43000000e+08,
#        5.15000000e+08, 1.43025340e+08, 2.20800000e+08]), 'q1': 4420000.0, 'med': 16500000.0, 'q3': 38730470.0}]

# %% [markdown]
# * label: tick label for the boxplot
# * mean: arithmetic mean value
# * med: 50th percentile
# * q1: first quartile (25th percentile)
# * q3: third quartile (75th percentile)
# * cilo: lower notch around the median
# * cihi: upper notch around the median
# * whislo: end of the lower whisker
# * whishi: end of the upper whisker
# * fliers: outliers
# * iqr: the difference between the upper quartile and the lower quartile.

# %%
stas1 = pd.DataFrame.from_dict(boxplot_stats(df["funding_total_usd"].values))
stas1 = stas1.drop(["fliers", "iqr"], axis=1)
stas1
# Out:
#       mean     cilo     cihi   whishi  whislo      q1   med       q3
# 0 4.03e+07 9.37e+06 1.06e+07 9.41e+07     100 1.4e+06 1e+07 3.87e+07

# %%
#creating categories of these numerical values based on the output from the describe data. Also creating new column for the categories
bins = [-1, 100, 1.4e+06, 9.37e+06, 1e+07, 1.06e+07, 3.87e+07, 4.03e+07, 9.41e+07, np.inf]
labels=["level_0", "level_1", "level_2", "level_3", "level_4", "level_5", "level_6", "level_7", "level_8"]
cat_invest = pd.cut(df["funding_total_usd"], bins = bins, labels=labels)
#labeling total investment values as low, low medium, high medium and high based on their descriptive summary. 
df.insert(0,'cat_total_funding',cat_invest) # creating new column called cat_total_investment

# %%
stas2 = pd.DataFrame.from_dict(boxplot_stats(df["funding_day"].values))
stas2 = stas2.drop(["fliers", "iqr"], axis=1)
stas2
# Out:
#       mean  cilo  cihi   whishi  whislo  q1  med       q3
# 0 1.53e+03   581   637 4.29e+03       0 153  609 1.81e+03

# %%
#creating categories of these numerical values based on the output from the describe data. Also creating new column for the categories
bins = [-1, 0, 153, 581, 609, 637, 1.53e+03, 1.81e+03, 4.29e+03, np.inf]
labels=["level_0", "level_1", "level_2", "level_3", "level_4", "level_5", "level_6", "level_7", "level_8"]
cat_invest = pd.cut(df["funding_day"], bins = bins, labels=labels)
#labeling total investment values as low, low medium, high medium and high based on their descriptive summary. 
df.insert(1,'cat_funding_day',cat_invest) # creating new column called cat_total_investment

# %%
df["funding_range_1_2"].max()
# Out:
# 33628.0

# %%
stas3 = pd.DataFrame.from_dict(boxplot_stats(df["funding_range_1_2"].values))
stas3 = stas3.drop(["fliers", "iqr"], axis=1)
stas3
# Out:
#    mean  cilo  cihi   whishi  whislo  q1  med  q3
# 0   568 -14.4  14.4 2.13e+03       0   0    0 854

# %%
bins = [-1, 0, 14, 568, 854, 2.13e+03, np.inf]
labels=["level_0", "level_1", "level_2", "level_3", "level_4", "level_5"]
cat_invest = pd.cut(df["funding_range_1_2"], bins = bins, labels=labels)
#labeling total investment values as low, low medium, high medium and high based on their descriptive summary. 
df.insert(2,'cat_funding_range_1_2',cat_invest) # creating new column called cat_total_investment

# %%
stas4 = pd.DataFrame.from_dict(boxplot_stats(df["company_age"].values))
stas4 = stas4.drop(["fliers", "iqr"], axis=1)
stas4
# Out:
#    mean  cilo  cihi  whishi  whislo  q1  med  q3
# 0  17.4  15.8  16.2      34       7  12   16  21

# %%
bins = [-1, 6, 11, 14.8, 15, 15.2, 16.4, 20, 33, np.inf]
labels=["level_0", "level_1", "level_2", "level_3", "level_4", "level_5", "level_6", "level_7", "level_8"]
cat_invest = pd.cut(df["company_age"], bins = bins, labels=labels)
#labeling total investment values as low, low medium, high medium and high based on their descriptive summary. 
df.insert(3,'cat_company_age',cat_invest) # creating new column called cat_total_investment

# %%
df.head(5)
# Out:
#   cat_total_funding cat_funding_day cat_funding_range_1_2 cat_company_age  \
# 0           level_2         level_5               level_0         level_1
# 1           level_1         level_1               level_0         level_2
# 2           level_2         level_0               level_2         level_2
# 3           level_1         level_1               level_2         level_1
# 4           level_5         level_7               level_0         level_7
#
#            name  funding_total_usd   status  funding_rounds  \
# 0  1 Mainstream              5e+06  success               1
# 1  1000 Markets              5e+05  success               1
# 2  1000memories           2.54e+06  success               2
# 3       100Plus           1.25e+06  success               2
# 4      1010data            3.5e+07  success               1
#
#            Industry_Group  funding_day  funding_range_1_2  company_age  \
# 0  Information Technology     1.11e+03                  0           10
# 1      Media & Publishing          134                  0           13
# 2  Information Technology            0                411           12
# 3            Data Science           47                 28           11
# 4  Information Technology     3.72e+03                  0           22
#
#   Continent_Name
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 8705
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cat_total_funding      8703 non-null   category
#  1   cat_funding_day        8703 non-null   category
#  2   cat_funding_range_1_2  8703 non-null   category
#  3   cat_company_age        8703 non-null   category
#  4   name                   8703 non-null   object
#  5   funding_total_usd      8703 non-null   float64
#  6   status                 8703 non-null   object
#  7   funding_rounds         8703 non-null   int64
#  8   Industry_Group         8703 non-null   object
#  9   funding_day            8703 non-null   float64
#  10  funding_range_1_2      8703 non-null   float64
#  11  company_age            8703 non-null   int64
#  12  Continent_Name         8703 non-null   object
# dtypes: category(4), float64(3), int64(2), object(4)
# memory usage: 715.2+ KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier



from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, r2_score, f1_score, confusion_matrix, roc_curve, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.metrics import plot_precision_recall_curve, precision_score, recall_score

# %%
labelencoder = LabelEncoder()
df['cat_total_funding'] = labelencoder.fit_transform(df['cat_total_funding'] )
df["cat_funding_day"] = labelencoder.fit_transform(df["cat_funding_day"])
df['cat_funding_range_1_2'] = labelencoder.fit_transform(df['cat_funding_range_1_2'])
df['cat_company_age'] = labelencoder.fit_transform(df['cat_company_age'])

# %%
df.head()
# Out:
#    cat_total_funding  cat_funding_day  cat_funding_range_1_2  cat_company_age  \
# 0                  2                5                      0                0
# 1                  1                1                      0                1
# 2                  2                0                      2                1
# 3                  1                1                      2                0
# 4                  5                7                      0                5
#
#            name  funding_total_usd   status  funding_rounds  \
# 0  1 Mainstream              5e+06  success               1
# 1  1000 Markets              5e+05  success               1
# 2  1000memories           2.54e+06  success               2
# 3       100Plus           1.25e+06  success               2
# 4      1010data            3.5e+07  success               1
#
#            Industry_Group  funding_day  funding_range_1_2  company_age  \
# 0  Information Technology     1.11e+03                  0           10
# 1      Media & Publishing          134                  0           13
# 2  Information Technology            0                411           12
# 3            Data Science           47                 28           11
# 4  Information Technology     3.72e+03                  0           22
#
#   Continent_Name
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 8705
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cat_total_funding      8703 non-null   int32
#  1   cat_funding_day        8703 non-null   int32
#  2   cat_funding_range_1_2  8703 non-null   int32
#  3   cat_company_age        8703 non-null   int32
#  4   name                   8703 non-null   object
#  5   funding_total_usd      8703 non-null   float64
#  6   status                 8703 non-null   object
#  7   funding_rounds         8703 non-null   int64
#  8   Industry_Group         8703 non-null   object
#  9   funding_day            8703 non-null   float64
#  10  funding_range_1_2      8703 non-null   float64
#  11  company_age            8703 non-null   int64
#  12  Continent_Name         8703 non-null   object
# dtypes: float64(3), int32(4), int64(2), object(4)
# memory usage: 815.9+ KB

# %%
df.to_csv("data_DL.csv")

# %% [markdown]
# # Deep learning

# %%
import tensorflow as tf 
import os
import io
import warnings

# %%
url = "https://raw.githubusercontent.com/huynam1012/Projet_jedha/main/data_DL.csv"
df = pd.read_csv(url).drop('Unnamed: 0', axis = 'columns')
df = df.dropna()
df.head(5)
# Out:
#   cat_total_funding cat_funding_day cat_funding_range_1_2 cat_company_age  \
# 0           level_2         level_5               level_0         level_1
# 1           level_1         level_1               level_0         level_2
# 2           level_2         level_0               level_2         level_1
# 3           level_1         level_1               level_2         level_1
# 4           level_5         level_7               level_0         level_7
#
#            name  funding_total_usd   status  funding_rounds  \
# 0  1 Mainstream              5e+06  success               1
# 1  1000 Markets              5e+05  success               1
# 2  1000memories           2.54e+06  success               2
# 3       100Plus           1.25e+06  success               2
# 4      1010data            3.5e+07  success               1
#
#            Industry_Group  funding_day  funding_range_1_2  company_age  \
# 0  Information Technology     1.11e+03                  0            9
# 1      Media & Publishing          134                  0           12
# 2  Information Technology            0                411           11
# 3            Data Science           47                 28           10
# 4  Information Technology     3.72e+03                  0           21
#
#   Continent_Name
# 0  North America
# 1  North America
# 2  North America
# 3  North America
# 4  North America

# %%
df1 = df[["cat_total_funding", "cat_funding_day", "cat_funding_range_1_2", "cat_company_age", "funding_rounds", "status"]]
df1.head()
# Out:
#   cat_total_funding cat_funding_day cat_funding_range_1_2 cat_company_age  \
# 0           level_2         level_5               level_0         level_1
# 1           level_1         level_1               level_0         level_2
# 2           level_2         level_0               level_2         level_1
# 3           level_1         level_1               level_2         level_1
# 4           level_5         level_7               level_0         level_7
#
#    funding_rounds   status
# 0               1  success
# 1               1  success
# 2               2  success
# 3               2  success
# 4               1  success

# %%
df2 = df1.copy()

# %%
df2["text"]= df2[df2.columns[0:5]].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
df2.head()
# Out:
#   cat_total_funding cat_funding_day cat_funding_range_1_2 cat_company_age  \
# 0           level_2         level_5               level_0         level_1
# 1           level_1         level_1               level_0         level_2
# 2           level_2         level_0               level_2         level_1
# 3           level_1         level_1               level_2         level_1
# 4           level_5         level_7               level_0         level_7
#
#    funding_rounds   status                               text
# 0               1  success  level_2 level_5 level_0 level_1 1
# 1               1  success  level_1 level_1 level_0 level_2 1
# 2               2  success  level_2 level_0 level_2 level_1 2
# 3               2  success  level_1 level_1 level_2 level_1 2
# 4               1  success  level_5 level_7 level_0 level_7 1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 8702
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cat_total_funding      8703 non-null   object
#  1   cat_funding_day        8703 non-null   object
#  2   cat_funding_range_1_2  8703 non-null   object
#  3   cat_company_age        8703 non-null   object
#  4   funding_rounds         8703 non-null   int64
#  5   status                 8703 non-null   object
#  6   text                   8703 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 543.9+ KB

# %% [markdown]
# ## Encoder decoder

# %%
usefull_cols = ['text', 'status']
df3 = df2[usefull_cols]
df3.head(5)
# Out:
#                                 text   status
# 0  level_2 level_5 level_0 level_1 1  success
# 1  level_1 level_1 level_0 level_2 1  success
# 2  level_2 level_0 level_2 level_1 2  success
# 3  level_1 level_1 level_2 level_1 2  success
# 4  level_5 level_7 level_0 level_7 1  success

# %%
df3["padded_status"] = df3.iloc[:,1].apply(lambda x: "<start> "+x)
df3.head()
# Out:
# <ipython-input-31-c7a28a1eca4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["padded_status"] = df3.iloc[:,1].apply(lambda x: "<start> "+x)
#                                 text   status    padded_status
# 0  level_2 level_5 level_0 level_1 1  success  <start> success
# 1  level_1 level_1 level_0 level_2 1  success  <start> success
# 2  level_2 level_0 level_2 level_1 2  success  <start> success
# 3  level_1 level_1 level_2 level_1 2  success  <start> success
# 4  level_5 level_7 level_0 level_7 1  success  <start> success

# %%
tokenizer_text = tf.keras.preprocessing.text.Tokenizer()
tokenizer_status = tf.keras.preprocessing.text.Tokenizer(filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n')

# %%
tokenizer_text.fit_on_texts(df3["text"])
tokenizer_status.fit_on_texts(df3["padded_status"])

# %%
df3["text_indices"] = tokenizer_text.texts_to_sequences(df3["text"])
df3["status_indices"] = tokenizer_status.texts_to_sequences(df3["status"])
df3["padded_status_indices"] = tokenizer_status.texts_to_sequences(df3["padded_status"])
df3.head()
# Out:
# <ipython-input-34-27a2d21968ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["text_indices"] = tokenizer_text.texts_to_sequences(df3["text"])
# <ipython-input-34-27a2d21968ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["status_indices"] = tokenizer_status.texts_to_sequences(df3["status"])
# <ipython-input-34-27a2d21968ce>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["padded_status_indices"] = tokenizer_status.texts_to_sequences(df3["padded_status"])
#                                 text   status    padded_status  \
# 0  level_2 level_5 level_0 level_1 1  success  <start> success
# 1  level_1 level_1 level_0 level_2 1  success  <start> success
# 2  level_2 level_0 level_2 level_1 2  success  <start> success
# 3  level_1 level_1 level_2 level_1 2  success  <start> success
# 4  level_5 level_7 level_0 level_7 1  success  <start> success
#
#                   text_indices status_indices padded_status_indices
# 0  [1, 3, 1, 5, 1, 4, 1, 2, 2]            [2]                [1, 2]
# 1  [1, 2, 1, 2, 1, 4, 1, 3, 2]            [2]                [1, 2]
# 2  [1, 3, 1, 4, 1, 3, 1, 2, 3]            [2]                [1, 2]
# 3  [1, 2, 1, 2, 1, 3, 1, 2, 3]            [2]                [1, 2]
# 4  [1, 5, 1, 6, 1, 4, 1, 6, 2]            [2]                [1, 2]

# %%
df3["padded_status_indices_clean"] = df3["padded_status_indices"].apply(lambda x: x[:-1])
df3.head()
# Out:
#                                 text   status    padded_status  \
# 0  level_2 level_5 level_0 level_1 1  success  <start> success
# 1  level_1 level_1 level_0 level_2 1  success  <start> success
# 2  level_2 level_0 level_2 level_1 2  success  <start> success
# 3  level_1 level_1 level_2 level_1 2  success  <start> success
# 4  level_5 level_7 level_0 level_7 1  success  <start> success
#
#                   text_indices status_indices padded_status_indices  \
# 0  [1, 3, 1, 5, 1, 4, 1, 2, 2]            [2]                [1, 2]
# 1  [1, 2, 1, 2, 1, 4, 1, 3, 2]            [2]                [1, 2]
# 2  [1, 3, 1, 4, 1, 3, 1, 2, 3]            [2]                [1, 2]
# 3  [1, 2, 1, 2, 1, 3, 1, 2, 3]            [2]                [1, 2]
# 4  [1, 5, 1, 6, 1, 4, 1, 6, 2]            [2]                [1, 2]
#
#   padded_status_indices_clean
# 0                         [1]
# 1                         [1]
# 2                         [1]
# 3                         [1]
# 4                         [1]

# %%
# Use of Keras to create token sequences of the same length
padded_text_indices = tf.keras.preprocessing.sequence.pad_sequences(df3["text_indices"], padding="post")
padded_status_indices = tf.keras.preprocessing.sequence.pad_sequences(df3["status_indices"], padding="post")
teacher_forcing_status = tf.keras.preprocessing.sequence.pad_sequences(df3["padded_status_indices_clean"], padding="post")

# %%
# Visualization of the shape of one of the tensors
padded_text_indices.shape
# Out:
# (8703, 9)

# %%
padded_status_indices.shape
# Out:
# (8703, 1)

# %%
teacher_forcing_status.shape
# Out:
# (8703, 1)

# %%
from sklearn.model_selection import train_test_split
status_train, status_val, text_train, text_val, teacher_train, teacher_val =  train_test_split(padded_status_indices,
                                                                                   padded_text_indices,
                                                                                   teacher_forcing_status,
                                                                                   test_size=0.2)

# %%
text_train.shape
# Out:
# (6962, 9)

# %%
status_train.shape
# Out:
# (6962, 1)

# %%
teacher_train.shape
# Out:
# (6962, 1)

# %%
n_lstm = 64
n_embed = 128
text_len = padded_text_indices.shape[1]
status_len = padded_status_indices.shape[1]
vocab_size_text = len(tokenizer_text.word_index)
vocab_size_status = len(tokenizer_status.word_index)

# %%
encoder_input = tf.keras.Input(shape=(text_len))
encoder_embed = tf.keras.layers.Embedding(input_dim=vocab_size_text+1, output_dim=n_embed)
encoder_lstm = tf.keras.layers.LSTM(n_lstm, return_state=True)

encoder_embed_ouput = encoder_embed(encoder_input)
encoder_output = encoder_lstm(encoder_embed_ouput)

encoder = tf.keras.Model(inputs = encoder_input, outputs = encoder_output)

# %%
encoder(text_train)
# Out:
# [<tf.Tensor: shape=(6962, 64), dtype=float32, numpy=
#  array([[-0.00587419, -0.00878249, -0.00046644, ..., -0.00993339,
#          -0.00937564,  0.00274477],
#         [ 0.00584099,  0.01561377,  0.01770003, ..., -0.00903135,
#           0.01174267,  0.02661009],
#         [-0.00891662,  0.00333268, -0.00240626, ..., -0.00680353,
#          -0.02127367,  0.0049767 ],
#         ...,
#         [-0.00702248,  0.01570719,  0.00630582, ..., -0.00754488,
#           0.00437106,  0.01445807],
#         [ 0.00400125,  0.00208029, -0.00690971, ..., -0.00762537,
#           0.00150863, -0.00127603],
#         [-0.00495104,  0.01483072,  0.00776022, ..., -0.00912174,
#           0.00821188,  0.00865687]], dtype=float32)>,
#  <tf.Tensor: shape=(6962, 64), dtype=float32, numpy=
#  array([[-0.00587419, -0.00878249, -0.00046644, ..., -0.00993339,
#          -0.00937564,  0.00274477],
#         [ 0.00584099,  0.01561377,  0.01770003, ..., -0.00903135,
#           0.01174267,  0.02661009],
#         [-0.00891662,  0.00333268, -0.00240626, ..., -0.00680353,
#          -0.02127367,  0.0049767 ],
#         ...,
#         [-0.00702248,  0.01570719,  0.00630582, ..., -0.00754488,
#           0.00437106,  0.01445807],
#         [ 0.00400125,  0.00208029, -0.00690971, ..., -0.00762537,
#           0.00150863, -0.00127603],
#         [-0.00495104,  0.01483072,  0.00776022, ..., -0.00912174,
#           0.00821188,  0.00865687]], dtype=float32)>,
#  <tf.Tensor: shape=(6962, 64), dtype=float32, numpy=
#  array([[-0.01166562, -0.01746346, -0.00093052, ..., -0.01973521,
#          -0.01882756,  0.00541883],
#         [ 0.01161642,  0.03095887,  0.03568984, ..., -0.01799686,
#           0.02339086,  0.0533714 ],
#         [-0.0177638 ,  0.0066452 , -0.00478953, ..., -0.0134668 ,
#          -0.04277544,  0.00980251],
#         ...,
#         [-0.01382012,  0.03145607,  0.01240231, ..., -0.0148999 ,
#           0.00870649,  0.02920471],
#         [ 0.00817371,  0.00426145, -0.01399506, ..., -0.01513117,
#           0.00303879, -0.00255697],
#         [-0.01012307,  0.03040983,  0.01575184, ..., -0.01807976,
#           0.01645747,  0.01735015]], dtype=float32)>]

# %%
decoder_input = tf.keras.Input(shape=(status_len))
decoder_embed = tf.keras.layers.Embedding(input_dim=vocab_size_status+1, 
                                          output_dim=n_embed)
decoder_lstm = tf.keras.layers.LSTM(n_lstm, return_sequences=True, return_state=True)
decoder_pred = tf.keras.layers.Dense(vocab_size_status+1, activation="sigmoid") #sigmoid, softmax

decoder_embed_output = decoder_embed(decoder_input) # teacher forcing happens here
# the decoder input is actually the padded target we created earlier, remember
# if target is: [91, 47, 89, 21, 62]
# the decoder input will be: [0, 91, 47, 89, 21]
decoder_lstm_output, _, _ = decoder_lstm(decoder_embed_output, initial_state=encoder_output[1:])
# in the step described above the decoder receives the encoder state as its
# initial state.
decoder_output = decoder_pred(decoder_lstm_output)
# then the dense layer will convert the vector representation for each element
# in the sequence into a probability distribution across all possible tokens
# in the vocabulary!

decoder = tf.keras.Model(inputs = [encoder_input,decoder_input], outputs = decoder_output)
# all we need to do is put the model together using the input output framework!

# %%
decoder([text_train,teacher_train])
# Out:
# <tf.Tensor: shape=(6962, 1, 4), dtype=float32, numpy=
# array([[[0.50190437, 0.49536043, 0.5022378 , 0.49884295]],
#
#        [[0.50262743, 0.4965876 , 0.49900046, 0.49881795]],
#
#        [[0.5021157 , 0.4994708 , 0.50302976, 0.49856272]],
#
#        ...,
#
#        [[0.50000066, 0.49693713, 0.49788824, 0.49792102]],
#
#        [[0.4987614 , 0.49352393, 0.49572185, 0.49803814]],
#
#        [[0.50105   , 0.496018  , 0.496744  , 0.49725977]]], dtype=float32)>

# %%
decoder_state_input_h = tf.keras.Input(shape=(n_lstm,))
decoder_state_input_c = tf.keras.Input(shape=(n_lstm,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
# at the first step of the inference, these input will be respectively the
# hidden state and C state of the encoder model
# for following steps, they will become the hidden and C state from the decoder
# itself since the input sequence is unknown we will have to predict step by step
# using a loop

decoder_input_inf = tf.keras.Input(shape=(1))
decoder_embed_output = decoder_embed(decoder_input_inf)
# the decoder input here is of shape 1 because we will feed the elements in the 
# sequence one by one

decoder_outputs, state_h, state_c = decoder_lstm(decoder_embed_output, initial_state=decoder_states_inputs)
# the lstm layer works in the same way, the output from the embedding is used
# and the decoder state is used as described above

decoder_states = [state_h, state_c]
# we store the lstm states in a specific object as we'll have to use them as 
# initial state for the next inference step

decoder_outputs = decoder_pred(decoder_outputs)
# the lstm output is then converted to a probability distribution over the
# target vocabulary

decoder_inf = tf.keras.Model(inputs = [decoder_input_inf, decoder_states_inputs], 
                     outputs = [decoder_outputs, decoder_states])
# Finally we wrap up the model building by setting up the inputs and outputs

# %%
decoder.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
history_deco = decoder.fit(x=[text_train, teacher_train], y=status_train,epochs=50, 
                validation_data=([text_val, teacher_val], status_val))
# Out:
# Epoch 1/50
# 218/218 [==============================] - 7s 13ms/step - loss: 0.6750 - sparse_categorical_accuracy: 0.6772 - val_loss: 0.5478 - val_sparse_categorical_accuracy: 0.7392
# Epoch 2/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5479 - sparse_categorical_accuracy: 0.7356 - val_loss: 0.5400 - val_sparse_categorical_accuracy: 0.7392 0.5481 - sparse_categorical_accuracy: 0
# Epoch 3/50
# 218/218 [==============================] - 2s 10ms/step - loss: 0.5469 - sparse_categorical_accuracy: 0.7347 - val_loss: 0.5309 - val_sparse_categorical_accuracy: 0.7450
# Epoch 4/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5426 - sparse_categorical_accuracy: 0.7380 - val_loss: 0.5302 - val_sparse_categorical_accuracy: 0.7461
# Epoch 5/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5449 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5301 - val_sparse_categorical_accuracy: 0.7410
# Epoch 6/50
# 218/218 [==============================] - 2s 10ms/step - loss: 0.5451 - sparse_categorical_accuracy: 0.7374 - val_loss: 0.5278 - val_sparse_categorical_accuracy: 0.7438
# Epoch 7/50
# 218/218 [==============================] - 2s 10ms/step - loss: 0.5435 - sparse_categorical_accuracy: 0.7383 - val_loss: 0.5258 - val_sparse_categorical_accuracy: 0.7438
# Epoch 8/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5411 - sparse_categorical_accuracy: 0.7409 - val_loss: 0.5273 - val_sparse_categorical_accuracy: 0.7450
# Epoch 9/50
# 218/218 [==============================] - 2s 10ms/step - loss: 0.5390 - sparse_categorical_accuracy: 0.7407 - val_loss: 0.5279 - val_sparse_categorical_accuracy: 0.7444
# Epoch 10/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5375 - sparse_categorical_accuracy: 0.7438 - val_loss: 0.5412 - val_sparse_categorical_accuracy: 0.7392
# Epoch 11/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5374 - sparse_categorical_accuracy: 0.7404 - val_loss: 0.5267 - val_sparse_categorical_accuracy: 0.7455
# Epoch 12/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5369 - sparse_categorical_accuracy: 0.7404 - val_loss: 0.5231 - val_sparse_categorical_accuracy: 0.7478
# Epoch 13/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5373 - sparse_categorical_accuracy: 0.7354 - val_loss: 0.5278 - val_sparse_categorical_accuracy: 0.7410
# Epoch 14/50
# 218/218 [==============================] - 2s 7ms/step - loss: 0.5377 - sparse_categorical_accuracy: 0.7397 - val_loss: 0.5248 - val_sparse_categorical_accuracy: 0.7415
# Epoch 15/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5387 - sparse_categorical_accuracy: 0.7404 - val_loss: 0.5225 - val_sparse_categorical_accuracy: 0.7478
# Epoch 16/50
# 218/218 [==============================] - 2s 7ms/step - loss: 0.5394 - sparse_categorical_accuracy: 0.7392 - val_loss: 0.5222 - val_sparse_categorical_accuracy: 0.7450
# Epoch 17/50
# 218/218 [==============================] - 2s 7ms/step - loss: 0.5363 - sparse_categorical_accuracy: 0.7420 - val_loss: 0.5211 - val_sparse_categorical_accuracy: 0.7450
# Epoch 18/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5385 - sparse_categorical_accuracy: 0.7394 - val_loss: 0.5259 - val_sparse_categorical_accuracy: 0.7507
# Epoch 19/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5352 - sparse_categorical_accuracy: 0.7413 - val_loss: 0.5228 - val_sparse_categorical_accuracy: 0.7530
# Epoch 20/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5355 - sparse_categorical_accuracy: 0.7422 - val_loss: 0.5199 - val_sparse_categorical_accuracy: 0.7461
# Epoch 21/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5355 - sparse_categorical_accuracy: 0.7422 - val_loss: 0.5313 - val_sparse_categorical_accuracy: 0.7341
# Epoch 22/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5367 - sparse_categorical_accuracy: 0.7383 - val_loss: 0.5212 - val_sparse_categorical_accuracy: 0.7490
# Epoch 23/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5373 - sparse_categorical_accuracy: 0.7387 - val_loss: 0.5204 - val_sparse_categorical_accuracy: 0.7490
# Epoch 24/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5356 - sparse_categorical_accuracy: 0.7406 - val_loss: 0.5222 - val_sparse_categorical_accuracy: 0.7513
# Epoch 25/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5359 - sparse_categorical_accuracy: 0.7410 - val_loss: 0.5210 - val_sparse_categorical_accuracy: 0.7473
# Epoch 26/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5345 - sparse_categorical_accuracy: 0.7419 - val_loss: 0.5210 - val_sparse_categorical_accuracy: 0.7507
# Epoch 27/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5349 - sparse_categorical_accuracy: 0.7417 - val_loss: 0.5275 - val_sparse_categorical_accuracy: 0.7392
# Epoch 28/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5333 - sparse_categorical_accuracy: 0.7425 - val_loss: 0.5218 - val_sparse_categorical_accuracy: 0.7536
# Epoch 29/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5342 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5204 - val_sparse_categorical_accuracy: 0.7461
# Epoch 30/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5354 - sparse_categorical_accuracy: 0.7429 - val_loss: 0.5188 - val_sparse_categorical_accuracy: 0.7496
# Epoch 31/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5336 - sparse_categorical_accuracy: 0.7400 - val_loss: 0.5208 - val_sparse_categorical_accuracy: 0.7473
# Epoch 32/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5343 - sparse_categorical_accuracy: 0.7426 - val_loss: 0.5245 - val_sparse_categorical_accuracy: 0.7387
# Epoch 33/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5339 - sparse_categorical_accuracy: 0.7417 - val_loss: 0.5216 - val_sparse_categorical_accuracy: 0.7461
# Epoch 34/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5331 - sparse_categorical_accuracy: 0.7406 - val_loss: 0.5184 - val_sparse_categorical_accuracy: 0.7490
# Epoch 35/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5331 - sparse_categorical_accuracy: 0.7432 - val_loss: 0.5188 - val_sparse_categorical_accuracy: 0.7507
# Epoch 36/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5326 - sparse_categorical_accuracy: 0.7422 - val_loss: 0.5198 - val_sparse_categorical_accuracy: 0.7461
# Epoch 37/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.7438 - val_loss: 0.5342 - val_sparse_categorical_accuracy: 0.7387
# Epoch 38/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5325 - sparse_categorical_accuracy: 0.7425 - val_loss: 0.5180 - val_sparse_categorical_accuracy: 0.7473
# Epoch 39/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5321 - sparse_categorical_accuracy: 0.7436 - val_loss: 0.5270 - val_sparse_categorical_accuracy: 0.7410
# Epoch 40/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5316 - sparse_categorical_accuracy: 0.7430 - val_loss: 0.5215 - val_sparse_categorical_accuracy: 0.7496
# Epoch 41/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5327 - sparse_categorical_accuracy: 0.7415 - val_loss: 0.5196 - val_sparse_categorical_accuracy: 0.7507
# Epoch 42/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5316 - sparse_categorical_accuracy: 0.7412 - val_loss: 0.5224 - val_sparse_categorical_accuracy: 0.7478
# Epoch 43/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5319 - sparse_categorical_accuracy: 0.7425 - val_loss: 0.5182 - val_sparse_categorical_accuracy: 0.7461
# Epoch 44/50
# 218/218 [==============================] - 2s 9ms/step - loss: 0.5299 - sparse_categorical_accuracy: 0.7445 - val_loss: 0.5177 - val_sparse_categorical_accuracy: 0.7496
# Epoch 45/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5312 - sparse_categorical_accuracy: 0.7416 - val_loss: 0.5196 - val_sparse_categorical_accuracy: 0.7576
# Epoch 46/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5311 - sparse_categorical_accuracy: 0.7400 - val_loss: 0.5195 - val_sparse_categorical_accuracy: 0.7473
# Epoch 47/50
# 218/218 [==============================] - 2s 7ms/step - loss: 0.5314 - sparse_categorical_accuracy: 0.7427 - val_loss: 0.5265 - val_sparse_categorical_accuracy: 0.7415
# Epoch 48/50
# 218/218 [==============================] - 2s 7ms/step - loss: 0.5301 - sparse_categorical_accuracy: 0.7449 - val_loss: 0.5186 - val_sparse_categorical_accuracy: 0.7513
# Epoch 49/50
# 218/218 [==============================] - 2s 8ms/step - loss: 0.5300 - sparse_categorical_accuracy: 0.7433 - val_loss: 0.5220 - val_sparse_categorical_accuracy: 0.7450
# Epoch 50/50
# 218/218 [==============================] - 2s 7ms/step - loss: 0.5295 - sparse_categorical_accuracy: 0.7455 - val_loss: 0.5258 - val_sparse_categorical_accuracy: 0.7381

# %%
history_deco.history.keys()
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
plt.plot(history_deco.history["loss"], color="b", label='train')
plt.plot(history_deco.history["val_loss"], color="r", label='validation')
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %%
plt.plot(history_deco.history['sparse_categorical_accuracy'], color="b", label='train')
plt.plot(history_deco.history['val_sparse_categorical_accuracy'], color="r",  label='validation')
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Enregistrez les meilleurs paramètres

# %%
decoder.save("sigmoid_0.0005_Sparse.h5")
json.dump(decoder.history.history, open("sigmoid_0.0005_Sparse.json", 'w'))

# %%
sigmoid_0_0005_Sparse = json.load(open("sigmoid_0.0005_Sparse.json", 'r'))

# %%
plt.plot(sigmoid_0_0005_Sparse["loss"], color="b", label='train')
plt.plot(sigmoid_0_0005_Sparse["val_loss"], color="r", label='validation')
plt.ylabel("Loss")
plt.xlabel("Epochs")
#plt.ylim(1.38, 1.4)
plt.legend()
plt.show()

# %%
plt.plot(sigmoid_0_0005_Sparse['sparse_categorical_accuracy'], color="b", label='train')
plt.plot(sigmoid_0_0005_Sparse['val_sparse_categorical_accuracy'], color="r", label='validation')
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.legend()
plt.show()
